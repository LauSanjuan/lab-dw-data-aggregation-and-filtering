# %% [markdown]
# # Lab | Data Aggregation and Filtering

# %% [markdown]
# Objective: Use Python programming techniques to filter and order data subsets, group data by one or more variables, and use aggregation functions to obtain insights, and derive meaningful conclusions from the data.

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing first data cleaning, formatting, and structuring.

# %% [markdown]
# Start by reading the dataset, standardizing column names, dealing with null values and creating the month column. You can do so by using the functions you developed in previous labs, or by reading the clean dataset you saved in the last lab `data structuring and combining`.

# %% [markdown]
# Then, answer the following questions:

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

# %% [markdown]
# 2. Analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign.

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %% [markdown]
# 4. Find the median customer lifetime value by education level and gender.

# %% [markdown]
# 5. Find the maximum, minimum, and average number of open complaints by state and policy type.

# %% [markdown]
# 6. The marketing team wants to analyze the number of policies sold by state and month.
#
# Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %% [markdown]
# 7. Display a new DataFrame that contains the number of policies sold by month by state for the top 3 states with the highest number of policies sold.
#
# *Hint:*
# - *To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.*
# - *Next, you will select the top 3 states with the highest number of policies sold.*
# - *Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.*

# %% [markdown]
# 8. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
#
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.

# %% [markdown]
# External Resources for Data Filtering: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %%
import pandas as pd
marketing_customer_analysis = pd.read_csv('../lab-dw-data-structuring-and-combining/clean_marketing_customer_analysis.csv')
marketing_customer_analysis
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  Washington              6857.519928      Yes
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
marketing_customer_analysis = marketing_customer_analysis.drop(['unnamed:_0'],axis=1)
marketing_customer_analysis
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  Washington              6857.519928      Yes     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
# Checking for duplicates in the customer column
marketing_customer_analysis['customer'].duplicated().value_counts()
# Out:
# False    9134
# True     1776
# Name: customer, dtype: int64

# %%
# Removing duplicates in the customer column
marketing_customer_analysis.drop_duplicates(subset=['customer'],inplace=True,ignore_index=True)
marketing_customer_analysis['customer'].duplicated().value_counts()
# Out:
# False    9134
# Name: customer, dtype: int64

# %%
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response 
# of "Yes" to the last marketing campaign.
marketing_customer_analysis[(marketing_customer_analysis['total_claim_amount']>1000)&(marketing_customer_analysis['response']=='Yes')]
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 189   OK31456  California             11009.130490      Yes   Premium
# 236   YJ16163      Oregon             11009.130490      Yes   Premium
# 418   GW43195      Oregon             25807.063000      Yes  Extended
# 440   IP94270     Arizona             13736.132500      Yes   Premium
# 584   FJ28407  California              5619.689084      Yes   Premium
# 648   VV47792  California             25807.063000      Yes  Extended
# 674   QL45827  Washington             25807.063000      Yes  Extended
# 804   MA15172  California             10179.717040      Yes   Premium
# 1246  WA45944     Arizona             25807.063000      Yes  Extended
# 1384  YK65946      Oregon              8427.172486      Yes  Extended
# 1484  TU53781      Oregon              8427.172486      Yes  Extended
# 1525  VL84149      Oregon             25807.063000      Yes  Extended
# ...

# %%
# 2. Analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last 
# marketing campaign.
marketing_customer_analysis[(marketing_customer_analysis['response']=='Yes')].groupby(['policy_type','gender']).agg({'total_claim_amount':'mean'})
# Out:
#                        total_claim_amount
# policy_type    gender
# Corporate Auto F               431.835494
#                M               409.512313
# Personal Auto  F               452.641922
#                M               455.060737
# Special Auto   F               460.360832
#                M               414.799291

# %%
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states 
# where there are more than 500 customers.
customers_per_state=marketing_customer_analysis.groupby(['state']).agg({'customer':'count'})
display(customers_per_state)
customers_per_state[(customers_per_state['customer']>500)]
# Out:
#             customer
# state
# Arizona         1688
# California      3200
# Nevada           870
# Oregon          2600
# Washington       776
#             customer
# state
# Arizona         1688
# California      3200
# Nevada           870
# Oregon          2600
# Washington       776

# %%
# 4. Find the median customer lifetime value by education level and gender.
marketing_customer_analysis.groupby(['education','gender']).agg({'customer_lifetime_value':'median'})
# Out:
#                              customer_lifetime_value
# education            gender
# Bachelor             F                   5678.050167
#                      M                   5555.830205
# College              F                   5621.789489
#                      M                   5989.773931
# Doctor               F                   5332.462694
#                      M                   5620.587184
# High School or Below F                   6044.020038
#                      M                   6176.700392
# Master               F                   5801.128252
#                      M                   5617.956917

# %%
# 5. Find the maximum, minimum, and average number of open complaints by state and policy type.
marketing_customer_analysis.groupby(['state','policy_type']).agg({'number_of_open_complaints':['max','min','mean']})
# Out:
#                           number_of_open_complaints
#                                                 max  min      mean
# state      policy_type
# Arizona    Corporate Auto                       5.0  0.0  0.370482
#            Personal Auto                        5.0  0.0  0.383894
#            Special Auto                         3.0  0.0  0.246753
# California Corporate Auto                       4.0  0.0  0.295756
#            Personal Auto                        5.0  0.0  0.377197
#            Special Auto                         5.0  0.0  0.460177
# Nevada     Corporate Auto                       5.0  0.0  0.438144
#            Personal Auto                        5.0  0.0  0.401244
#            Special Auto                         5.0  0.0  0.545455
# Oregon     Corporate Auto                       4.0  0.0  0.336466
#            Personal Auto                        5.0  0.0  0.368177
#            Special Auto                         5.0  0.0  0.325397
# ...

# %%
# 6. The marketing team wants to analyze the number of policies sold by state and month.
marketing_customer_analysis.groupby(['state','months']).agg({'number_of_policies':'sum'})
# Out:
#                    number_of_policies
# state      months
# Arizona    1                     2702
#            2                     2441
# California 1                     5081
#            2                     4423
# Nevada     1                     1333
#            2                     1096
# Oregon     1                     4127
#            2                     3629
# Washington 1                     1184
#            2                     1077

# %%
# 7. Display a new DataFrame that contains the number of policies sold by month by state for the top 3 states with the highest 
# number of policies sold.
policies_month_state=marketing_customer_analysis.groupby(['state','months']).agg({'number_of_policies':'sum'}).reset_index().pivot(columns='months',index='state')
policies_month_state['total'] = policies_month_state[('number_of_policies', 1)] + policies_month_state[  ('number_of_policies', 2)]
policies_month_state.sort_values(by='total', ascending=False).head(3)
# Out:
#            number_of_policies       total
# months                      1     2
# state
# California               5081  4423  9504
# Oregon                   4127  3629  7756
# Arizona                  2702  2441  5143

# %%
# 8. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
total_samples_per_channel = marketing_customer_analysis.groupby(['sales_channel']).agg({'response':'count'})
total_yes_per_channel = marketing_customer_analysis[(marketing_customer_analysis['response']=='Yes')].groupby(['sales_channel']).agg({'response':'count'})
total_yes_per_channel / total_samples_per_channel
# Out:
#                response
# sales_channel
# Agent          0.184067
# Branch         0.111025
# Call Center    0.105949
# Web            0.113962
